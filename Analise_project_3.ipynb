# %%
import pandas as pd

result = pd.read_pickle('./metrics/metrics_summary.pkl').set_index('set')

result_jm1 = result.loc['jm1']

result_jm1.round(3).transpose()
# Out:
# set             jm1    jm1    jm1    jm1    jm1      jm1    jm1    jm1    jm1  \
# hardness       None   None   None   None   None     None   Hard   Hard   Hard
# strategy      F-KNU  F-KNE  F-OLA  F-LCA  F-MCB  Bagging  F-KNU  F-KNE  F-OLA
# mean_auc_roc  0.765  0.968  0.832  0.672  0.832    0.568  0.647  0.952  0.765
# std_auc_roc   0.006  0.004  0.005  0.007  0.004    0.011  0.015  0.008  0.016
# mean_acc      0.789  0.982  0.872  0.686  0.872    0.812  0.624  0.937  0.792
# std_acc       0.004  0.003  0.002  0.009  0.002    0.002  0.021  0.011  0.015
# mean_f1       0.715  0.971  0.809  0.613  0.809    0.575  0.603  0.926  0.753
# std_f1        0.004  0.005  0.003  0.007  0.003    0.017  0.017  0.012  0.015
# mean_g1        0.73  0.971  0.811  0.643  0.812    0.625  0.633   0.93  0.755
# std_g1        0.005  0.005  0.003  0.006  0.002    0.006  0.013  0.011  0.015
#
# set             jm1    jm1      jm1    jm1    jm1    jm1    jm1    jm1  \
# ...

# %%
result_cm1 = result.loc['cm1']

result_cm1.round(3).transpose()
# Out:
# set             cm1    cm1    cm1    cm1    cm1      cm1    cm1    cm1    cm1  \
# hardness       None   None   None   None   None     None   Hard   Hard   Hard
# strategy      F-KNU  F-KNE  F-OLA  F-LCA  F-MCB  Bagging  F-KNU  F-KNE  F-OLA
# mean_auc_roc  0.864  0.987  0.931  0.824  0.941    0.563  0.661  0.984  0.853
# std_auc_roc   0.037   0.01   0.02  0.033  0.019     0.03  0.076  0.019  0.094
# mean_acc      0.919  0.994  0.963  0.849  0.969    0.896  0.516  0.973  0.878
# std_acc       0.016  0.003   0.01  0.021  0.012    0.008  0.066  0.032  0.072
# mean_f1       0.808  0.984  0.904   0.71  0.919    0.578  0.481  0.958  0.806
# std_f1        0.036  0.009  0.024   0.03  0.028    0.041  0.057  0.051  0.088
# mean_g1       0.816  0.984  0.906  0.746  0.921    0.611  0.621  0.962  0.819
# std_g1        0.035  0.009  0.023  0.027  0.027    0.038  0.055  0.045  0.087
#
# set             cm1    cm1      cm1    cm1    cm1    cm1    cm1    cm1  \
# ...
